# %% [markdown]
# https://chatgpt.com/share/69220889-0f0c-8008-890b-29140ca8de1f

# %% [markdown]
# 2️⃣ مدیریت فونت‌های مختلف
#
# برای اینکه قسمت‌هایی که فارسی هستند با Vazir و بقیه متن‌ها (مثلاً انگلیسی یا بخش‌هایی که فونت فارسی ندارند) با فونت دیگر نمایش داده شوند، می‌توانیم کلاس اختصاصی فونت بسازیم:

# %% [markdown]
# ```css
#
# .farsi-text {
#     font-family: 'Vazir', sans-serif;
# }
#
#
# .eng-text {
#     font-family: 'Poppins', sans-serif;
# }
# ```

# %% [markdown]
# حالا فقط کافیست هر جایی که متن فارسی است، کلاس farsi-text و هر جایی که انگلیسی است، کلاس eng-text بگذاری:

# %% [markdown]
# ```html
# <h1 class="farsi-text text-right">میوه‌های فصلی خوشمزه</h1>
# <h2 class="eng-text text-left">Fresh Seasonal Fruits</h2>
# ```

# %% [markdown]
# 3️⃣ جمع‌بندی روش پیشنهادی
#
# کل body فقط فونت پایه داشته باشد (بدون direction):

# %% [markdown]
# ```html
# <body> { font-family: 'Poppins', sans-serif; } </body>
# ```

# %% [markdown]
# متن‌های فارسی با کلاس جدا و راست‌چین:

# %% [markdown]
# ```html
# <p class="farsi-text text-right">متن فارسی</p>
# ```

# %% [markdown]
# متن‌های انگلیسی یا وسط‌چین با کلاس جدا:

# %% [markdown]
# ```html
# <p class="eng-text text-left">English Text</p>
# <p class="farsi-text text-center">متن فارسی وسط‌چین</p>
# ```

# %% [markdown]
# ✅ این روش همه چیز را قابل کنترل می‌کند:
#
# فونت فارسی یا انگلیسی
#
# راست‌چین، چپ‌چین، یا وسط‌چین
#
# بدون خراب کردن Layout و Grid

# %% [markdown]
# 	text-right → متن راست‌چین
#
# 	text-center → متن وسط‌چین
#
# 	text-left → متن چپ‌چین (برای انگلیسی یا فارسی سمت چپ)
#
# 👆برای مشاهده کد نمونه دابل کلیک کنید👆
#
# <!-- نمونه :
# 	<div class="homepage-slider">
# 		<div class="single-homepage-slider homepage-bg-1">
# 			<div class="container">
# 				<div class="row">
# 					<div class="col-md-12 col-lg-7 offset-lg-1 offset-xl-0">
# →						<div class="hero-text text-right">
# 							<div class="hero-text-tablecell">
# 								<p class="subtitle">تازه و ارگانیک</p>
# 								<h1>میوه‌های فصلی خوشمزه</h1>
# 								<div class="hero-btns text-center">
# 									<a href="shop.html" class="boxed-btn">کلکسیون میوه</a>
# 									<a href="contact.html" class="bordered-btn">تماس با ما</a>
# 								</div>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div> -->

# %% [markdown]
# _____________________________________________________________

# %% [markdown]
# قسمت های حدف شده از کد

# %% [markdown]
# قسمت روزشمار تبلیغاتی
#
# cart banner section

# %% [markdown]
# ```html
#
# <!-- cart banner section -->
# 	<section class="cart-banner pt-100 pb-100">
# 		<div class="container">
# 			<div class="row clearfix">
# 				<!--Image Column-->
# 				<div class="image-column col-lg-6">
# 					<div class="image">
# 						<div class="price-box">
# 							<div class="inner-price">
# 								<span class="price">
# 									<strong>30%</strong> <br> off per kg
# 								</span>
# 							</div>
# 						</div>
# 						<img src="assets/img/a.jpg" alt="">
# 					</div>
# 				</div>
# 				<!--Content Column-->
# 				<div class="content-column col-lg-6">
# 					<h3><span class="orange-text">Deal</span> of the month</h3>
# 					<h4>Hikan Strwaberry</h4>
# 					<div class="text">
# 						Quisquam minus maiores repudiandae nobis, minima saepe id, fugit ullam similique! Beatae, minima quisquam molestias facere ea. Perspiciatis unde omnis iste natus error sit voluptatem accusant
# 					</div>
# 					<!--Countdown Timer-->
# 					<div class="time-counter">
# 						<div class="time-countdown clearfix" data-countdown="2020/2/01">
# 							<div class="counter-column">
# 								<div class="inner"><span class="count">00</span>Days</div>
# 							</div>
# 							<div class="counter-column">
# 								<div class="inner"><span class="count">00</span>Hours</div>
# 							</div>
# 							<div class="counter-column">
# 								<div class="inner"><span class="count">00</span>Mins</div>
# 							</div>
# 							<div class="counter-column">
# 								<div class="inner"><span class="count">00</span>Secs</div>
# 							</div>
# 						</div>
# 					</div>
# 					<a href="cart.html" class="cart-btn mt-3"><i class="fas fa-shopping-cart"></i> افزودن به سبد</a>
# 				</div>
# 			</div>
# 		</div>
# 	</section>
#     <!-- end cart banner section -->
# ```

# %% [markdown]
#  بنر تبلیغاتی قسمت پایین
#
# shop banner

# %% [markdown]
# ```html
# 	<!-- shop banner -->
# 	<section class="shop-banner">
#     	<div class="container">
#         	<h3>December sale is on! <br><span class="orange-text">Discount...</span></h3>
#             <div class="sale-percent"><span>Sale! <br> Upto</span>50% <span>off</span></div>
#             <a href="products.html" class="cart-btn btn-lg">Shop Now</a>
#         </div>
#     </section>
# 	<!-- end shop banner -->
# ```

# %% [markdown]
# قسمت تبلیغات ویدیویی در صفحه اصلی
#
# advertisement section

# %% [markdown]
# ```html
# 	<!-- advertisement section -->
# 	<div class="abt-section mb-150">
# 		<div class="container">
# 			<div class="row">
# 				<div class="col-lg-6 col-md-12">
# 					<div class="abt-text text-right">
# 						<p class="top-sub">از سال 1404</p>
# 						<h2> ما<span class="orange-text">بازانو</span> هستیم </h2>
# 						<p>.اینجا بازانوعه؛ جایی که اعتماد، از دل محله می‌جوشه</p>
# 						<p>در بازانو، بهترین و حرفه‌ای‌ترین اصناف رو معرفی می‌کنیم؛ کسانی که با وجود فعالیت در مراکز تخصصی صنف خودشون، از اهالی همین محل هستن و ریشه‌شون به خود ما برمی‌گرده</p>
# 						<a href="about.html" class="boxed-btn mt-4">بیشتر بدانید</a>
# 					</div>
# 				</div>
# 				<div class="col-lg-6 col-md-12">
# 					<div class="adv-vid-bg">
# 						<a href="https://www.aparat.com/v/zsbsedo" class="video-play-btn popup-youtube"><i class="fas fa-play"></i></a>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<!-- end advertisement section -->
# ```html

# %% [markdown]
# قسمت رزومه اشخاص
#
# testimonail-section

# %% [markdown]
# ```html
# 	<div class="testimonail-section mt-150 mb-150">
# 		<div class="container">
# 			<div class="row">
# 				<div class="col-lg-10 offset-lg-1 text-center">
# 					<div class="testimonial-sliders">
# 						<div class="single-testimonial-slider">
# 							<div class="client-avater">
# 								<img src="assets/img/avaters/avatar1.png" alt="">
# 							</div>
# 							<div class="client-meta">
# 								<h3>Saira Hakim <span>Local shop owner</span></h3>
# 								<p class="testimonial-body">
# 									" Sed ut perspiciatis unde omnis iste natus error veritatis et  quasi architecto beatae vitae dict eaque ipsa quae ab illo inventore Sed ut perspiciatis unde omnis iste natus error sit voluptatem accusantium "
# 								</p>
# 								<div class="last-icon">
# 									<i class="fas fa-quote-right"></i>
# 								</div>
# 							</div>
# 						</div>
# 						<div class="single-testimonial-slider">
# 							<div class="client-avater">
# 								<img src="assets/img/avaters/avatar2.png" alt="">
# 							</div>
# 							<div class="client-meta">
# 								<h3>David Niph <span>Local shop owner</span></h3>
# 								<p class="testimonial-body">
# 									" Sed ut perspiciatis unde omnis iste natus error veritatis et  quasi architecto beatae vitae dict eaque ipsa quae ab illo inventore Sed ut perspiciatis unde omnis iste natus error sit voluptatem accusantium "
# 								</p>
# 								<div class="last-icon">
# 									<i class="fas fa-quote-right"></i>
# 								</div>
# 							</div>
# 						</div>
# 						<div class="single-testimonial-slider">
# 							<div class="client-avater">
# 								<img src="assets/img/avaters/avatar3.png" alt="">
# 							</div>
# 							<div class="client-meta">
# 								<h3>Jacob Sikim <span>Local shop owner</span></h3>
# 								<p class="testimonial-body">
# 									" Sed ut perspiciatis unde omnis iste natus error veritatis et  quasi architecto beatae vitae dict eaque ipsa quae ab illo inventore Sed ut perspiciatis unde omnis iste natus error sit voluptatem accusantium "
# 								</p>
# 								<div class="last-icon">
# 									<i class="fas fa-quote-right"></i>
# 								</div>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# ```

# %% [markdown]
# روزشمار بنر تخفیف event advertisment

# %% [markdown]
# ```html
# 		<!-- event advertisment -->
#     <section class="cart-banner pt-100 pb-100">
#     	<div class="container">
#         	<div class="row clearfix">
#
#             	<div class="image-column col-lg-6">
#                 	<div class="image">
#                     	<div class="price-box">
#                         	<div class="inner-price">
#                                 <span class="price">
#                                     <strong>۳۰٪</strong> <br> تخفیف هر کیلو
#                                 </span>
#                             </div>
#                         </div>
#                     	<img src="assets/img/a.jpg" alt="">
#                     </div>
#                 </div>
#
#                 <div class="content-column col-lg-6">
# 					<h3><span class="orange-text">پیشنهاد</span> ماه</h3>
#                     <h4>توت فرنگی هیکن</h4>
#                     <div class="text">توضیحات کوتاه درباره این محصول و کیفیت بالای آن. لورم ایپسوم متن ساختگی.</div>
#
#                     <div class="time-counter">
# 						<div class="time-countdown clearfix" data-countdown="2020/2/01">
# 							<div class="counter-column"><div class="inner"><span class="count">99</span>روز</div></div>
# 							<div class="counter-column"><div class="inner"><span class="count">99</span>ساعت</div></div>
# 							<div class="counter-column"><div class="inner"><span class="count">99</span>دقیقه</div></div>
# 							<div class="counter-column"><div class="inner"><span class="count">99</span>ثانیه</div></div>
# 						</div>
# 					</div>
#
#                 	<a href="cart.html" class="cart-btn mt-3"><i class="fas fa-shopping-cart"></i> افزودن به سبد</a>
#                 </div>
#
#             </div>
#         </div>
#     </section>
# ```
